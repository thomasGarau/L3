# %%
import pandas as pd
import seaborn as sns

# %%
data = pd.read_csv('bird.csv', delimiter=',')
data
# Out:
#       id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw  \
# 0      0  80.78  6.68  72.01   4.88  41.81  3.70   5.50  4.03  38.70  3.84
# 1      1  88.91  6.63  80.53   5.59  47.04  4.30  80.22  4.51  41.50  4.01
# 2      2  79.97  6.37  69.26   5.28  43.07  3.90  75.35  4.04  38.31  3.34
# 3      3  77.65  5.70  65.76   4.77  40.04  3.52  69.17  3.40  35.78  3.41
# 4      4  62.80  4.84  52.09   3.73  33.95  2.72  56.27  2.96  31.88  3.13
# ..   ...    ...   ...    ...    ...    ...   ...    ...   ...    ...   ...
# 415  415  17.96  1.63  19.25   1.33  18.36  1.54  31.25  1.33  21.99  1.15
# 416  416  19.21  1.64  20.76   1.49  19.24  1.45  33.21  1.28  23.60  1.15
# 417  417  18.79  1.63  19.83   1.53  20.96  1.43  34.45  1.41  22.86  1.21
# 418  418  20.38  1.78  22.53   1.50  21.35  1.48  36.09  1.53  25.98  1.24
# 419  419  17.89  1.44  19.26   1.10  17.62  1.34  29.81  1.24  21.69  1.05
#
#     type
# 0     SW
# 1     SW
# 2     SW
# 3     SW
# 4     SW
# ...

# %%
data[data['huml']>0].describe()
# Out:
#                id        huml        humw       ulnal       ulnaw        feml  \
# count  419.000000  419.000000  419.000000  417.000000  418.000000  417.000000
# mean   209.183771   64.650501    4.370573   69.115372    3.597249   36.882806
# std    121.359591   53.834549    2.854617   58.784775    2.186747   20.001951
# min      0.000000    9.850000    1.140000   14.090000    1.000000   11.830000
# 25%    104.500000   25.170000    2.190000   28.050000    1.870000   21.280000
# 50%    209.000000   44.180000    3.500000   43.710000    2.945000   31.090000
# 75%    313.500000   90.310000    5.810000   97.520000    4.770000   47.130000
# max    419.000000  420.000000   17.840000  422.000000   12.000000  117.070000
#
#              femw        tibl        tibw        tarl        tarw
# count  418.000000  417.000000  418.000000  418.000000  418.000000
# mean     3.222249   64.685851    3.183230   39.230670    2.931651
# std      2.025813   37.880663    2.083241   23.212091    2.188038
# ...

# %%
sns.scatterplot(data=data, x='huml', y='humw', hue='type')
# Out:
# <AxesSubplot:xlabel='huml', ylabel='humw'>

# %%
#supprime toute les ligne comportant un champ
#drop null pour supprimer une ligne contenant un champ null
data = data.dropna()

# %%
#comme sont nom l'indique
data=data.drop_duplicates()

# %%
#compte le nombre de données
data['type'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0      SW
# 1      SW
# 2      SW
# 3      SW
# 4      SW
#        ..
# 415    SO
# 416    SO
# 417    SO
# 418    SO
# 419    SO
# Name: type, Length: 413, dtype: object>
